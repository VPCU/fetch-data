# %%
import IPython

IPython.Application.instance().kernel.do_shutdown(True)

import sys
py_path = '/home/haorui/moco-test'
if py_path not in sys.path:
    sys.path.append(py_path)

# %run /home/haorui/moco-test/graphsaint/mocodict/pretrain.py\
    --data_prefix /home/haorui/Downloads/fetch-data/data/22mnews \
    --pretrain_config /home/haorui/Downloads/fetch-data/kd-news.yml
# Out:
# Loading training data..
# Done loading training data..
# TOTAL NUM OF PARAMS = 220928
# START PHASE    0
# sampling 200 subgraphs:   time = 1.729 sec
# the amount of subgraphs: 6600
# /home/haorui/moco-test/graphsaint/mocodict/minibatch_pretrain.py:190: RuntimeWarning: divide by zero encountered in true_divide
#   val = np.clip(self.norm_loss_train[v] / self.norm_aggr_train[i_s : i_e], 0, 1e4)
# Epoch    0
# corrupt time = 395.3613 sec,	number of subgraphs = 104
# diffusion    1/104  subgraph time = 53.0552 sec
# diffusion    2/104  subgraph time = 51.2642 sec
# diffusion    3/104  subgraph time = 46.0515 sec
# diffusion    4/104  subgraph time = 32.7125 sec
# diffusion    5/104  subgraph time = 38.3447 sec
# diffusion    6/104  subgraph time = 29.7623 sec
# diffusion    7/104  subgraph time = 31.9827 sec
# diffusion    8/104  subgraph time = 33.2410 sec
# diffusion    9/104  subgraph time = 66.1143 sec
# diffusion   10/104  subgraph time = 42.6868 sec
# ...
